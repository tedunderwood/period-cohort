# %% [markdown]
# # Short story model
#
# The code provided here extracts a short story corpus and a novel corpus from our master metadata, selecting volumes by using words in the title. ("Other" and "stories" select for short stories. "A novel," without "stories" or "tales" anywhere in the title, selects for novels.)
#
# Then we collect topic proportions for those volumes, and train a model to distinguish short stories from novels.
#
# We do this two ways. First we select a test set at random by choosing individual volumes. This provides 80.5% accuracy. But since many authors tend to be short story writers or novelists for much of their career, there's some possibility that this model will "cheat" by learning to recognize specific writers, instead of really learning a generalizable model of the forms.
#
# To avoid fooling ourselves in this way, we re-run the experiment in the second half of the notebook while rigorously separating the authors in the training set from authors in the test set. This avoids "leaking" information about authors from test to train.
#
# There is still a kind of information leakage happening here, because *the topic model itself* is trained on all volumes at once. This means that the topics are shaped, in some small part, by the ~150 volumes in our test set, which may have helped to create topics that are specifically reflective of those volumes. It's unsupervised modeling, of course; it's not like the topic model knows these are/aren't short stories. So the information leakage is very indirect. But still, it's possible that we will get slightly higher accuracy than we would have if we trained a model without those 150 test volumes and used it to predict their topic proportions.
#
# However, the effect of 150 volumes in a topic model of 29,000 + is likely to be extremely small. And we're sampling authors 20 times to average our random variation. It would really be prohibitively difficult to train 20 topic models with 20 different sets of held-out authors. I think for the purpose of this project, it's sufficient to note that the actual accuracy we would get in the wild might be a couple tenths of a percentage point lower. A difference of that scale won't matter for the point we're illustrating.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

# %%
meta = pd.read_csv('../metadata/finalcorpus.tsv', sep = '\t')
meta.head()
# Out:
#                       docid             hathi_author  \
# 0  loc.ark+=13960=t49p3qv8g  Thwing, Edward P[ayson]
# 1  loc.ark+=13960=t7wm1fd5j            Jones, Joseph
# 2        nyp.33433081882650        Allan-Olney, Mary
# 3            uva.x030742146                      NaN
# 4        nyp.33433074386792      of Samosata. Lucian
#
#                                          hathi_title  authordate  birthyear  \
# 0  Outdoor life in Europe, sketches of men and ma...         NaN        NaN
# 1                              Major Jones's travels  1812-1882.     1812.0
# 2                                 The new Virginians         NaN        NaN
# 3  The Growing world; or, Progress of civilizatio...         NaN        NaN
# 4                            A traveller's true tale         NaN        NaN
#
#    deathyear  chi_date  ukw_date  copyright_date  firstpub  ...  distances  \
# 0        NaN       NaN       NaN             NaN      1880  ...        NaN
# 1        NaN       NaN       NaN             NaN      1880  ...        NaN
# 2        NaN       NaN       NaN             NaN      1880  ...        NaN
# 3        NaN       NaN       NaN             NaN      1880  ...        NaN
# 4        NaN       NaN       NaN             NaN      1880  ...        NaN
#
#   copyright_corpus  manual_corpus  us_national  pubdate_known  authof3ormore  \
# 0            False          False        False          False          False
# 1            False          False        False          False          False
# 2            False          False        False          False          False
# 3            False          False        False          False          False
# 4            False          False        False          False          False
#
#    tokens  pagesinchunk  tokensperpage  omnibus
# 0   45865            54        849.352    False
# 1   42135           204        206.544    False
# 2   32052           244        131.361    False
# 3  374115           420        890.750    False
# 4   11848           128         92.562    False
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Create the story and novel subcorpora

# %%
print(meta.shape)
metaclean = meta[~pd.isnull(meta.hathi_title)]
print(metaclean.shape)
stories = metaclean[(metaclean.hathi_title.str.contains('stories')) & 
                    (metaclean.hathi_title.str.contains('other'))]
stories.shape
# Out:
# (29351, 23)
# (29311, 23)
# (722, 23)

# %%
stories.head()
# Out:
#                         docid                  hathi_author  \
# 93   uc2.ark+=13960=t3707xn80                   Perry, Nora
# 149  uc2.ark+=13960=t7gq6s478             Hawthorne, Julian
# 223        nyp.33433082525563  Arthur, T. S. (Timothy Shay)
# 233  uc2.ark+=13960=t5bc41d87           Besant, Walter, Sir
# 246        nyp.33433082525589  Arthur, T. S. (Timothy Shay)
#
#                                           hathi_title  authordate  birthyear  \
# 93   The tragedy of the unexpected, and other stories  1831-1896.     1831.0
# 149  Yellow-cap, and other fairy-stories for children  1846-1934.     1846.0
# 223            Who is the greatest? And other stories  1809-1885.     1809.0
# 233          The ten years' tenant, and other stories  1836-1901.     1836.0
# 246          Pierre, the organ-boy, and other stories  1809-1885.     1809.0
#
#      deathyear  chi_date  ukw_date  copyright_date  firstpub  ...  distances  \
# 93         NaN       NaN       NaN             NaN      1880  ...        NaN
# 149     1934.0       NaN    1880.0             NaN      1880  ...  53.797678
# 223        NaN       NaN       NaN             NaN      1881  ...        NaN
# 233        NaN       NaN       NaN             NaN      1881  ...        NaN
# 246        NaN       NaN       NaN             NaN      1881  ...        NaN
#
#     copyright_corpus  manual_corpus  us_national  pubdate_known  \
# 93             False          False        False          False
# 149            False           True         True           True
# 223            False          False        False          False
# 233            False          False        False          False
# 246            False          False        False          False
#
#      authof3ormore  tokens  pagesinchunk  tokensperpage  omnibus
# 93           False   37848           251        150.789    False
# 149           True   29201           242        120.665    False
# 223          False   25127           258         97.391    False
# 233          False   70571           297        237.613    False
# 246          False   25520           254        100.472    False
#
# [5 rows x 23 columns]

# %%
novels = metaclean[(~metaclean.hathi_title.str.contains('stories')) & 
                       (~metaclean.hathi_title.str.contains('tales')) &
                       (~metaclean.hathi_title.str.contains('Stories')) &
                       (~metaclean.hathi_title.str.contains('Tales')) &
                       ((metaclean.hathi_title.str.contains('a novel')) |
                        (metaclean.hathi_title.str.contains('A Novel')))
                      ]
novels.shape
# Out:
# (2362, 23)

# %%
selectedstories = stories.sample(710)
selectedstories.shape
# Out:
# (710, 23)

# %% [markdown]
# #### Get a subset of novels chronologically matching the story corpus

# %%
selectednovels = []
badidxes = []

for idx, row in selectedstories.iterrows():
    thisdate = row.firstpub
    options = novels[(novels.firstpub >= thisdate-2) & (novels.firstpub <= thisdate + 2)]
    found = False
    tried = 0
    while not found:
        chosen = options.sample(1)
        thisidx = chosen.index[0]
        tried += 1
        if thisidx not in selectednovels:
            selectednovels.append(thisidx)
            found = True
        if tried > len(options):
            badidxes.append(idx)
            break

print(len(selectednovels))
# Out:
# 710

# %%
selectedstories.shape
# Out:
# (710, 23)

# %%
selectedstories.sample(8)
# Out:
#                           docid                  hathi_author  \
# 13664        mdp.39015059406119              Phillpotts, Eden
# 11126            uva.x000157545          Mansfield, Katherine
# 10675            wu.89094611258        Levinger, Elma Ehrlich
# 11626        mdp.39015031304671             Tarkington, Booth
# 621    uc2.ark+=13960=t8kd26w5q  Turgenev, Ivan Sergi︠e︡evích
# 2157             wu.89098017650       Crowley, Mary Catherine
# 23773        mdp.39015030748860        Guerrero, Amadis María
# 24244        mdp.39015005062339          Aldiss, Brian Wilson
#
#                                              hathi_title  authordate  \
# 13664  They could do no other; a volume of stories by...  1862-1960.
# 11126                           Bliss, and other stories  1888-1923.
# 10675             Playmates in Egypt : and other stories       1887-
# 11626        The fascinating stranger : an other stories  1869-1946.
# 621              A reckless character, and other stories  1818-1883.
# 2157                   Happy-go-lucky, and other stories         NaN
# 23773                   The mainstream and other stories         NaN
# 24244                     Last orders, and other stories       1925-
#
#        birthyear  deathyear  chi_date  ukw_date  copyright_date  firstpub  \
# 13664     1862.0     1960.0       NaN       NaN          1931.0      1931
# 11126     1888.0     1923.0       NaN       NaN          1923.0      1921
# 10675     1887.0        NaN       NaN       NaN             NaN      1920
# 11626     1869.0     1946.0       NaN       NaN          1923.0      1923
# 621       1818.0        NaN       NaN       NaN             NaN      1883
# 2157         NaN        NaN       NaN       NaN             NaN      1889
# 23773        NaN        NaN       NaN       NaN             NaN      1975
# 24244     1925.0        NaN       NaN       NaN             NaN      1977
#
#        ...  distances copyright_corpus  manual_corpus  us_national  \
# 13664  ...  43.036775             True          False        False
# 11126  ...  35.137842             True          False        False
# 10675  ...        NaN            False          False        False
# 11626  ...  30.205821             True          False         True
# 621    ...        NaN            False          False        False
# 2157   ...        NaN            False          False        False
# 23773  ...        NaN            False          False        False
# 24244  ...        NaN            False          False        False
#
#        pubdate_known  authof3ormore  tokens  pagesinchunk  tokensperpage  \
# 13664           True           True   46845           238        196.828
# 11126           True           True   39050           238        164.076
# 10675          False          False   12224           112        109.143
# 11626           True           True   57555           416        138.353
# 621            False          False   47395           332        142.756
# 2157           False          False   18926           174        108.770
# 23773          False          False   15900            64        248.438
# 24244           True           True   42054           187        224.888
#
#        omnibus
# 13664    False
# 11126    False
# 10675    False
# 11626    False
# 621      False
# 2157     False
# 23773    False
# 24244    False
#
# [8 rows x 23 columns]

# %%
np.mean(selectedstories.firstpub)
# Out:
# 1941.5394366197183

# %% [markdown]
# ## Concatenate and write to tsv

# %%
selectednovels = novels.loc[selectednovels]
np.mean(selectednovels.firstpub)
# Out:
# 1941.5746478873239

# %%
selectedstories['genre'] = 'short'
selectednot['genre'] = 'long'
selectednovels['genre'] = 'long'

# %%
shortvsnovelmeta =  pd.concat([selectedstories, selectednovels])

# %%
shortmodelmeta.to_csv('shortmodelmeta.tsv', sep = '\t')

# %%
shortvsnovelmeta.to_csv('shortvsnovelmeta.tsv', sep = '\t')

# %% [markdown]
# ## Here something important happens in another notebook
#
# Sorry for the slightly confused sequence here. At this point execution moves to ```./topicdata/MakeShortStoryData.ipynb```, which combines ```shortvsnoveldata.tsv``` with raw topic model results to create aggregated book-level topic proportions.
#
# I load the results of that process below.

# %%
data = pd.read_csv('../topicdata/shortvsnoveldata.tsv', sep = '\t')
data.head()
# Out:
#          t0        t1        t2        t3        t4        t5        t6  \
# 0  0.000046  0.000005  0.009303  0.000024  0.000293  0.000046  0.000023
# 1  0.000538  0.001999  0.000090  0.000004  0.001392  0.000005  0.000082
# 2  0.000006  0.018790  0.023701  0.000004  0.000635  0.023100  0.000003
# 3  0.000006  0.000005  0.001850  0.000004  0.000010  0.005259  0.000002
# 4  0.000186  0.003024  0.007866  0.000049  0.000100  0.026803  0.000002
#
#          t7        t8        t9  ...      t199               docid  genre  \
# 0  0.000636  0.000169  0.012015  ...  0.000002  osu.32435001753706   long
# 1  0.006044  0.000007  0.046004  ...  0.001252         uc1.$b71369   long
# 2  0.003576  0.000692  0.000008  ...  0.000775  mdp.39015059384274  short
# 3  0.011151  0.000007  0.000112  ...  0.000317        uc1.b4449482   long
# 4  0.052632  0.001825  0.000007  ...  0.000002  mdp.39015063779485   long
#
#    birthyear  firstpub           hathi_author  \
# 0     1881.0      1945           Abbott, Jane
# 1     1871.0      1929  Adams, Samuel Hopkins
# 2     1889.0      1925          Aiken, Conrad
# 3        NaN      1975           Albert, Mimi
# 4     1892.0      1946     Aldington, Richard
#
#                                          hathi_title  us_national  \
# 0                  Mary Patten's daughters : a novel         True
# 1  The flagrant years : a novel of the beauty market         True
# 2                    Bring! bring! and other stories         True
# 3                     The second story man : a novel         True
# 4                   The romance of Casanova, a novel        False
#
#    authof3ormore   age
# 0           True  64.0
# 1           True  58.0
# 2           True  36.0
# 3          False   NaN
# 4           True  54.0
#
# [5 rows x 209 columns]

# %% [markdown]
# #### create a stratified training set

# %%
shortstorydata = data[data.genre == 'short'].sample(frac = 1)
longstorydata = data[data.genre == 'long'].sample(frac = 1)

# %%
training = pd.concat([shortstorydata.iloc[0: 638, 0:200], longstorydata.iloc[0: 638, 0:200]])

# %%
y = [1] * 638 + [0] * 638
len(y)
# Out:
# 1276

# %% [markdown]
# #### scale it and try logistic regression

# %%
scaler = StandardScaler()
training_scaled = scaler.fit_transform(training)

# %%
for constant in [0.00001, 0.0001, .001, .01, .1, 1, 10, 100, 1000]:
    logreg = LogisticRegression(C = constant, max_iter = 2000, penalty = 'l2')
    scores = cross_validate(logreg, training_scaled, y, scoring = 'accuracy', cv = 10)
    print(constant, round(np.mean(scores['test_score']), 4))
# Out:
# 1e-05 0.75
# 0.0001 0.761
# 0.001 0.772
# 0.01 0.7751
# 0.1 0.7728
# 1 0.7657
# 10 0.7633
# 100 0.7618
# 1000 0.7618

# %% [markdown]
# #### random forests work better though

# %%
deepdict = dict()
treedict = dict()

for numtrees in [275, 300, 325, 350, 375, 400, 425, 450]:
    treedict[numtrees] = []
    for deepness in [6, 8, 9, 10, 11, 12, 14, 16, 18]:
        if deepness not in deepdict:
            deepdict[deepness] = []
        randfor = RandomForestClassifier(n_estimators = numtrees, max_depth = deepness, n_jobs = 12)
        scores = cross_validate(randfor, training_scaled, y, scoring = 'accuracy', cv = 10)
        acc = np.mean(scores['test_score'])
        print(numtrees, deepness, round(acc, 4))
        deepdict[deepness].append(acc)
        treedict[numtrees].append(acc)
# Out:
# 275 6 0.7869
# 275 8 0.7924
# 275 9 0.7963
# 275 10 0.7987
# 275 11 0.8135
# 275 12 0.7853
# 275 14 0.7947
# 275 16 0.801
# 275 18 0.8033
# 300 6 0.7908
# 300 8 0.7893
# 300 9 0.7853
# 300 10 0.79
# 300 11 0.7908
# 300 12 0.7963
# 300 14 0.7947
# 300 16 0.7861
# 300 18 0.79
# 325 6 0.7893
# 325 8 0.7893
# 325 9 0.79
# 325 10 0.7971
# 325 11 0.7854
# 325 12 0.7948
# 325 14 0.7986
# 325 16 0.8041
# 325 18 0.7877
# 350 6 0.7908
# 350 8 0.8026
# 350 9 0.7963
# 350 10 0.7908
# 350 11 0.7924
# 350 12 0.7948
# 350 14 0.794
# 350 16 0.801
# 350 18 0.7987
# 375 6 0.7893
# 375 8 0.7901
# 375 9 0.7971
# 375 10 0.8034
# 375 11 0.7955
# 375 12 0.7877
# 375 14 0.7939
# 375 16 0.7995
# 375 18 0.805
# 400 6 0.7932
# 400 8 0.7994
# 400 9 0.7971
# 400 10 0.7979
# 400 11 0.8034
# 400 12 0.794
# 400 14 0.7995
# 400 16 0.7948
# 400 18 0.7987
# 425 6 0.7963
# 425 8 0.7908
# 425 9 0.7924
# 425 10 0.7947
# 425 11 0.7979
# 425 12 0.7987
# 425 14 0.7939
# 425 16 0.79
# 425 18 0.7995
# 450 6 0.7924
# 450 8 0.7916
# 450 9 0.8018
# 450 10 0.7971
# 450 11 0.805
# 450 12 0.7987
# 450 14 0.7994
# 450 16 0.794
# 450 18 0.7901

# %%
for numtrees in [275, 300, 325, 350, 375, 400, 425, 450]:
    print(numtrees, round(np.mean(treedict[numtrees]), 4))
for deepness in [6, 8, 9, 10, 11, 12, 14, 16, 18]:
    print(deepness, round(np.mean(deepdict[deepness]), 4))
# Out:
# 275 0.7969
# 300 0.7904
# 325 0.7929
# 350 0.7957
# 375 0.7957
# 400 0.7975
# 425 0.7949
# 450 0.7967
# 6 0.7911
# 8 0.7932
# 9 0.7946
# 10 0.7962
# 11 0.798
# 12 0.7938
# 14 0.7961
# 16 0.7963
# 18 0.7966

# %%
logreg = LogisticRegression(C = .01, max_iter = 1000)
logreg.fit(training_scaled, y)
coefs = logreg.coef_

# %% [markdown]
# #### create and scale the test set

# %%
test = pd.concat([shortstorydata.iloc[638: 710, 0:200], longstorydata.iloc[638: 710, 0:200]])

# %%
test_scaled = scaler.transform(test)

# %%
test_scaled.shape
# Out:
# (144, 200)

# %%
test_y = [1] * 72 + [0] * 72

# %%
predictions = logreg.predict(test_scaled)
sum(predictions == test_y) / len(test_y)
# Out:
# 0.7916666666666666

# %% [markdown]
# #### Here's an incautious volume-ramdomized accuracy figure, averaging 10 runs

# %%
accuracies = []
for iter in range(10):
    randfor = RandomForestClassifier(n_estimators = 400, max_depth = 18, n_jobs = 12)
    randfor.fit(training_scaled, y)
    predictions = randfor.predict(test_scaled)
    acc = sum(predictions == test_y) / len(test_y)
    accuracies.append(acc)
print(round(np.mean(accuracies), 4))
# Out:
# 0.8049

# %% [markdown]
# #### to find out which topics are predictive
#
# We use the logistic regression. It can be done with random forests, but it's clunkier.

# %%
coefficients = [(coef, idx) for idx, coef in enumerate(coefs[0])]
coefficients.sort()
coefficients
# Out:
# [(-0.24313424170915315, 157),
#  (-0.18221881645920668, 57),
#  (-0.16482749559310558, 88),
#  (-0.16307998478121052, 72),
#  (-0.15354510037825858, 64),
#  (-0.1516223297461646, 143),
#  (-0.14853967389492304, 154),
#  (-0.14597596888958125, 132),
#  (-0.1320005506090026, 165),
#  (-0.11787582289491635, 142),
#  (-0.11360792304335095, 115),
#  (-0.1135036554297054, 51),
#  (-0.10954962665155109, 78),
#  (-0.09736486798777723, 35),
#  (-0.09623186936286825, 197),
#  (-0.09236675241901808, 153),
#  (-0.09200542352828629, 38),
#  (-0.09130777223366604, 162),
#  (-0.09014211989820133, 190),
#  (-0.08796970176601236, 118),
#  (-0.08700708254459807, 69),
#  (-0.08579977130318572, 122),
#  (-0.08515277027618856, 59),
#  (-0.08502947516973054, 102),
#  (-0.07993376264788019, 84),
#  (-0.07875447216225773, 63),
#  (-0.07849987031144769, 151),
#  (-0.07848985303334048, 90),
#  (-0.07800521482846585, 198),
#  (-0.07692080840218442, 23),
#  (-0.07635007658512093, 34),
#  (-0.07556046741466166, 80),
#  (-0.07487629768155978, 0),
#  (-0.07453698156585857, 186),
#  (-0.07350502369240626, 83),
#  (-0.07021017544389946, 174),
#  (-0.06857493146516867, 125),
#  (-0.06684591242826024, 85),
#  (-0.06359480649793216, 100),
#  (-0.06135965858862483, 126),
#  (-0.05987411991083111, 41),
#  (-0.05904189401200595, 175),
#  (-0.057728273890398266, 55),
#  (-0.05510869550387264, 87),
#  (-0.05480196870910036, 176),
#  (-0.05397079072877252, 128),
#  (-0.05394542960659014, 99),
#  (-0.053789810906301964, 68),
#  (-0.05341926392091457, 119),
#  (-0.052753673434509596, 161),
#  (-0.05267507483281179, 45),
#  (-0.05240008294448314, 181),
#  (-0.05236929865977741, 3),
#  (-0.05077490680336832, 89),
#  (-0.05068940323808274, 108),
#  (-0.04930733395686852, 13),
#  (-0.04796051683298949, 49),
#  (-0.04791284088877165, 180),
#  (-0.045905406230184215, 124),
#  (-0.045600687550033436, 40),
#  (-0.04464055312172337, 6),
#  (-0.043308490918304986, 60),
#  (-0.0432293512412297, 170),
#  (-0.04115207456889897, 130),
#  (-0.04008635055013367, 56),
#  (-0.04004244956216259, 15),
#  (-0.037763899099767115, 98),
#  (-0.0356124129179503, 167),
#  (-0.03379947089283697, 121),
#  (-0.03354485094131468, 36),
#  (-0.03175196741441113, 139),
#  (-0.03171032794673699, 95),
#  (-0.030972761069303714, 196),
#  (-0.030378345066126782, 53),
#  (-0.030272149778265797, 116),
#  (-0.030097414686914223, 32),
#  (-0.030018225954984493, 33),
#  (-0.027294949085277565, 58),
#  (-0.025564531789065387, 19),
#  (-0.02389560456702348, 194),
#  (-0.02389043702683295, 46),
#  (-0.022973513741115188, 73),
#  (-0.022941100229371097, 11),
#  (-0.02183651203948575, 109),
#  (-0.02023382902053261, 152),
#  (-0.02012034377757556, 144),
#  (-0.01870565011108118, 81),
#  (-0.018103835306646686, 79),
#  (-0.015702143033329605, 172),
#  (-0.015411968366240557, 166),
#  (-0.015209031425859538, 113),
#  (-0.014215589181463987, 199),
#  (-0.012893215473303257, 171),
#  (-0.01219421347166106, 8),
#  (-0.011120701924524537, 31),
#  (-0.009774820824607669, 183),
#  (-0.00964583255521366, 65),
#  (-0.008968198198415473, 117),
#  (-0.007489504433338898, 178),
#  (-0.005628043918493523, 93),
#  (-0.005439126883219245, 86),
#  (-0.005204791060079159, 110),
#  (-0.0048041973351028, 42),
#  (-0.004748886535827559, 18),
#  (-0.004599543214555209, 44),
#  (-0.004512097013940273, 14),
#  (-0.0036940645581328597, 7),
#  (-0.0017302350699210194, 131),
#  (0.0006636084884908534, 12),
#  (0.0013724321507167982, 156),
#  (0.002799045780492893, 191),
#  (0.0031254283729507076, 50),
#  (0.003424562873385856, 173),
#  (0.0041176564026209, 163),
#  (0.004496416570193978, 37),
#  (0.006364449744073485, 185),
#  (0.006849876240856576, 106),
#  (0.006922370104764263, 135),
#  (0.0072463484174588155, 47),
#  (0.007900275426336825, 129),
#  (0.00946575210572134, 182),
#  (0.009630998305831273, 82),
#  (0.009829909379568541, 140),
#  (0.010272205453433318, 193),
#  (0.011186812075929328, 48),
#  (0.011876300172662606, 5),
#  (0.012203756894203182, 9),
#  (0.016138872366729, 76),
#  (0.017469528965447716, 138),
#  (0.018976910210361922, 70),
#  (0.01959978820154651, 17),
#  (0.02325425669730853, 96),
#  (0.024650470868584833, 77),
#  (0.02622566694792286, 112),
#  (0.02820987536433632, 92),
#  (0.029547186957274582, 187),
#  (0.031216891720669618, 192),
#  (0.03160333085768968, 111),
#  (0.03405629064813042, 29),
#  (0.034626373619639446, 195),
#  (0.03740204376927079, 107),
#  (0.039166465660206214, 62),
#  (0.043734416428635174, 74),
#  (0.04470562188913375, 155),
#  (0.046639219038713244, 169),
#  (0.04796335475494856, 1),
#  (0.05029315855770918, 150),
#  (0.051217757928439536, 30),
#  (0.05218177471688508, 54),
#  (0.052996213583603895, 188),
#  (0.05311772281473669, 94),
#  (0.053869409174693045, 168),
#  (0.05450434211638321, 123),
#  (0.054553348166951725, 134),
#  (0.05499241537591918, 26),
#  (0.05849074034201708, 145),
#  (0.05906376812385523, 104),
#  (0.06112150872538862, 177),
#  (0.06188350324394517, 147),
#  (0.06336465981574396, 2),
#  (0.0646724363508888, 67),
#  (0.06580641050879067, 16),
#  (0.07026828348739038, 39),
#  (0.07284322909093241, 20),
#  (0.0738985127497837, 159),
#  (0.07496961329802174, 136),
#  (0.07574104045858986, 189),
#  (0.07603743043669887, 4),
#  (0.07606957034203823, 28),
#  (0.07641716423325677, 21),
#  (0.07972749978550187, 158),
#  (0.08326689929190186, 25),
#  (0.08354249402860517, 148),
#  (0.08454620450518292, 52),
#  (0.08483125029632106, 127),
#  (0.08648577220665452, 61),
#  (0.09046247513133578, 137),
#  (0.09503038956960835, 146),
#  (0.09691224013878855, 101),
#  (0.10050773665177455, 24),
#  (0.10215182559837373, 133),
#  (0.11039542001619247, 179),
#  (0.11898411926167286, 22),
#  (0.12009953413956807, 114),
#  (0.1232340663445683, 27),
#  (0.13055841239618002, 164),
#  (0.13137824517911595, 43),
#  (0.13347435631541732, 160),
#  (0.13698203382960397, 184),
#  (0.14036338120566916, 97),
#  (0.14543224749274483, 10),
#  (0.1456099529190027, 91),
#  (0.14875177035842865, 66),
#  (0.15786461775645436, 120),
#  (0.17318852265348164, 149),
#  (0.17479251512883923, 71),
#  (0.178434433410561, 141),
#  (0.20250482287215454, 105),
#  (0.26744176935691877, 75),
#  (0.3485608594848846, 103)]

# %% [markdown]
# ## Let's do a more rigorous test with held-out authors
#
# It's possible that the model above learns to recognize specific short-story writers and novelists. Let's replicate the result while dividing by authors.

# %%
data.head()
# Out:
#          t0        t1        t2        t3        t4        t5        t6  \
# 0  0.000046  0.000005  0.009303  0.000024  0.000293  0.000046  0.000023
# 1  0.000538  0.001999  0.000090  0.000004  0.001392  0.000005  0.000082
# 2  0.000006  0.018790  0.023701  0.000004  0.000635  0.023100  0.000003
# 3  0.000006  0.000005  0.001850  0.000004  0.000010  0.005259  0.000002
# 4  0.000186  0.003024  0.007866  0.000049  0.000100  0.026803  0.000002
#
#          t7        t8        t9  ...      t199               docid  genre  \
# 0  0.000636  0.000169  0.012015  ...  0.000002  osu.32435001753706   long
# 1  0.006044  0.000007  0.046004  ...  0.001252         uc1.$b71369   long
# 2  0.003576  0.000692  0.000008  ...  0.000775  mdp.39015059384274  short
# 3  0.011151  0.000007  0.000112  ...  0.000317        uc1.b4449482   long
# 4  0.052632  0.001825  0.000007  ...  0.000002  mdp.39015063779485   long
#
#    birthyear  firstpub           hathi_author  \
# 0     1881.0      1945           Abbott, Jane
# 1     1871.0      1929  Adams, Samuel Hopkins
# 2     1889.0      1925          Aiken, Conrad
# 3        NaN      1975           Albert, Mimi
# 4     1892.0      1946     Aldington, Richard
#
#                                          hathi_title  us_national  \
# 0                  Mary Patten's daughters : a novel         True
# 1  The flagrant years : a novel of the beauty market         True
# 2                    Bring! bring! and other stories         True
# 3                     The second story man : a novel         True
# 4                   The romance of Casanova, a novel        False
#
#    authof3ormore   age
# 0           True  64.0
# 1           True  58.0
# 2           True  36.0
# 3          False   NaN
# 4           True  54.0
#
# [5 rows x 209 columns]

# %%
allauthors = set(data.hathi_author)

# %%
import random

# %% [markdown]
# #### selecting authors for the test set while ensuring that the genre balance stays even
#
# Randomly selecting authors won't do, because we should ensure that the balance of novels to short stories is nearly the same in test and training sets. We write a function to ensure that with a loop.

# %%
def get_test_authors(data):
    allauthors = set(data.hathi_author)
    # stratified sample
    selectedvols = 0
    selectedlong = 0
    selectedshort = 0
    testauthors = []
    while selectedvols < 150:
        author = random.sample(allauthors, 1)[0]
        df = data.loc[data.hathi_author == author, : ]
        shortcount = sum(df.genre == 'short')
        longcount = len(df) - shortcount
        allowed = False
        if selectedlong > selectedshort and longcount <= shortcount:
            allowed = True
        elif selectedlong < selectedshort and longcount >= shortcount:
            allowed = True
        elif selectedlong == selectedshort:
            allowed = True

        if allowed:
            testauthors.append(author)
            allauthors.remove(author)
            selectedlong += longcount
            selectedshort += shortcount
            selectedvols += (longcount + shortcount)

    print(selectedlong, selectedshort)
    return testauthors

# %% [markdown]
# Define another function that uses the list of testauthors to create test and training sets, scale them, and get the true class labels for both.

# %%
def make_test_and_train(data, testauthors):
    authtest = data.loc[data.hathi_author.isin(testauthors)]
    authtrain = data.loc[~data.hathi_author.isin(testauthors)]
    scaler2 = StandardScaler()
    authtrain_scaled = scaler2.fit_transform(authtrain.iloc[ : , 0: 200])
    authtest_scaled = scaler2.transform(authtest.iloc[ : , 0: 200])
    authtrain_y = (authtrain.genre == 'short')
    authtest_y = (authtest.genre == 'short')
    print(np.mean(authtrain_y), np.mean(authtest_y))
    
    return authtrain_scaled, authtest_scaled, authtrain_y, authtest_y

# %% [markdown]
# Now use the functions defined above to make 20 different test/train splits and average the accuracies.

# %%
accuracies = []
for iter in range(20):
    testauthors = get_test_authors(data)
    authtrain_scaled, authtest_scaled, authtrain_y, authtest_y = make_test_and_train(data, testauthors)
    randfor = RandomForestClassifier(n_estimators = 400, max_depth = 18, n_jobs = 12)
    randfor.fit(authtrain_scaled, authtrain_y)
    predictions = randfor.predict(authtest_scaled)
    acc = sum(predictions == authtest_y) / len(authtest_y)
    print(acc)
    accuracies.append(acc)
print(round(np.mean(accuracies), 4))
# Out:
# 75 76
# 0.4996059889676911 0.5033112582781457
# 0.8211920529801324
# 76 75
# 0.5003940110323088 0.4966887417218543
# 0.8211920529801324
# 75 75
# 0.5 0.5
# 0.7933333333333333
# 74 78
# 0.49842271293375395 0.5131578947368421
# 0.8223684210526315
# 75 75
# 0.5 0.5
# 0.8333333333333334
# 76 75
# 0.5003940110323088 0.4966887417218543
# 0.7549668874172185
# 76 74
# 0.5007874015748032 0.49333333333333335
# 0.8
# 75 75
# 0.5 0.5
# 0.78
# 74 76
# 0.49921259842519683 0.5066666666666667
# 0.7666666666666667
# 75 75
# 0.5 0.5
# 0.8
# 77 75
# 0.500788643533123 0.4934210526315789
# 0.8026315789473685
# 75 75
# 0.5 0.5
# 0.7933333333333333
# 75 75
# 0.4907630522088353 0.5657142857142857
# 0.8057142857142857
# 75 75
# 0.5 0.5
# 0.7866666666666666
# 72 78
# 0.49763779527559054 0.52
# 0.82
# 75 75
# 0.5 0.5
# 0.84
# 75 75
# 0.5 0.5
# 0.7866666666666666
# 75 75
# 0.5 0.5
# 0.82
# 75 75
# 0.4907630522088353 0.5657142857142857
# 0.8114285714285714
# 76 75
# 0.5003940110323088 0.4966887417218543
# 0.7549668874172185
# 0.8007

# %% [markdown]
# That's a more cautious number, and the number I'm going to report in the article.

# %%
print(round(np.mean(accuracies), 3))
# Out:
# 0.801
